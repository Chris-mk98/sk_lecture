# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

plt.rcParams['font.family'] ='Malgun Gothic'
plt.rcParams['axes.unicode_minus'] =False


class StudentScoreAnalysis:
    def __init__(self):
        
        self.students = [f'학생{i}' for i in range(1,21)]
        self.math = np.random.randint(50,100,len(self.students))
        self.english = np.random.randint(50,100,len(self.students))
        self.science = np.random.randint(50,100,len(self.students))

        self.data = {
            "Student" : self.students,
            "Math" : self.math,
            "English" : self.english,
            "Science" : self.science
        }

        self.df = pd.DataFrame(self.data)
        self.df['Total'] = self.df['Math']+self.df["English"]+self.df["Science"]

    def mean(self):
        math_mean = test.df['Math'].mean()
        english_mean = test.df['English'].mean()
        science_mean = test.df['Science'].mean()

        plt.bar(['수학', '영어', '과학'], [math_mean, english_mean, science_mean], color = 'orange')
        
        plt.title('과목별 평균 성적')
        plt.ylabel('평균 점수')

        plt.show()

    def top_5(self):
        top_idx = self.df['Total'].sort_values(ascending=False).head().index
        top_students = [self.df.iloc[i,0] for i in top_idx]
        top_mean = [self.df.iloc[i,4]/3 for i in top_idx]

        plt.bar(top_students, top_mean, color = 'green')

        plt.title('상위 5명의 평균 성적적')
        plt.ylabel('평균 점수수')

        plt.show()

# %%
test = StudentScoreAnalysis()

print(test.df)
top = test.df['Total'].sort_values(ascending=False).head().index

print([test.df.iloc[i,0] for i in top])
# Out:
#    Student  Math  English  Science  Total
# 0      학생1    52       56       81    189
# 1      학생2    92       52       88    232
# 2      학생3    90       73       52    215
# 3      학생4    61       54       50    165
# 4      학생5    60       90       95    245
# 5      학생6    81       95       60    236
# 6      학생7    51       83       90    224
# 7      학생8    76       72       59    207
# 8      학생9    77       90       62    229
# 9     학생10    96       72       53    221
# 10    학생11    65       54       88    207
# 11    학생12    98       82       61    241
# 12    학생13    59       84       53    196
# 13    학생14    65       89       57    211
# 14    학생15    97       61       56    214
# 15    학생16    99       82       71    252
# 16    학생17    83       52       55    190
# 17    학생18    81       83       55    219
# 18    학생19    52       87       52    191
# 19    학생20    80       86       90    256
# ['학생20', '학생16', '학생5', '학생12', '학생6']

# %%
test.mean()
test.top_5()
